# %%
import sys
# !{sys.executable} -m pip install astropy
# Out:
# Collecting astropy
#   Using cached astropy-7.2.0-cp311-abi3-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (2.4.5)
# Collecting pyerfa>=2.0.1.1 (from astropy)
#   Using cached pyerfa-2.0.1.5-cp39-abi3-win_amd64.whl.metadata (5.9 kB)
# Collecting astropy-iers-data>=0.2025.10.27.0.39.10 (from astropy)
#   Downloading astropy_iers_data-0.2026.5.18.1.11.28-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (26.0)
# Using cached astropy-7.2.0-cp311-abi3-win_amd64.whl (6.4 MB)
# Downloading astropy_iers_data-0.2026.5.18.1.11.28-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 2.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.7 MB/s  0:00:01
# Using cached pyerfa-2.0.1.5-cp39-abi3-win_amd64.whl (349 kB)
# Installing collected packages: pyerfa, astropy-iers-data, astropy
#
#    ------------- -------------------------- 1/3 [astropy-iers-data]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    -------------------------- ------------- 2/3 [astropy]
#    ---------------------------------------- 3/3 [astropy]
#
# Successfully installed astropy-7.2.0 astropy-iers-data-0.2026.5.18.1.11.28 pyerfa-2.0.1.5

# %%
from PIL.ImageColor import colormap
from astropy.constants.codata2010 import alpha
# !pip install pandas openpyxl

# !pip install matplotlib

# !pip install astropy
# Out:
# Requirement already satisfied: pandas in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (3.0.3)
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from pandas) (2.4.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from pandas) (2026.2)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Requirement already satisfied: matplotlib in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (2.4.5)
# Requirement already satisfied: packaging>=20.0 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: astropy in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (7.2.0)
# Requirement already satisfied: numpy>=1.24 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (2.4.5)
# Requirement already satisfied: pyerfa>=2.0.1.1 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (0.2026.5.18.1.11.28)
# Requirement already satisfied: PyYAML>=6.0.0 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in C:\Users\marya\miniconda3\envs\km3net-event\Lib\site-packages (from astropy) (26.0)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\marya\Downloads\result_web_fileVJzoaj.csv")

# convert MJD to datetime
from astropy.time import Time

t = Time(df['MJD'], format='mjd')
df['date'] = t.to_datetime()

df.head()
# Out:
#        MasterID     Mag  Magerr        RA      Dec          MJD  Blend  \
# 0  1.007030e+12  20.172   0.389  94.29311 -7.84727  54830.27443      0
# 1  1.007030e+12  19.705   0.300  94.29386 -7.84747  54830.27983      0
# 2  1.007030e+12  19.147   0.225  94.29360 -7.84727  54830.29053      0
# 3  1.007030e+12  20.453   0.457  94.29320 -7.84716  54830.29593      0
# 4  1.007030e+12  19.896   0.301  94.29340 -7.84745  55157.44256      0
#
#                      date
# 0 2008-12-30 06:35:10.752
# 1 2008-12-30 06:42:57.312
# 2 2008-12-30 06:58:21.792
# 3 2008-12-30 07:06:08.352
# 4 2009-11-22 10:37:17.184

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

df = pd.read_csv(r"C:\Users\marya\Downloads\result_web_fileFEkDcn.csv")
plt.style.use('default')
# Optional: clean column names
df.columns = df.columns.str.strip()

from astropy.time import Time

t = Time(df['MJD'], format='mjd')
df['date'] = t.to_datetime()

# Make folder for plots
os.makedirs("lightcurve_plots", exist_ok=True)

for master_id, group in df.groupby("MasterID"):

    date = group["date"]
    mag = group["Mag"]
    err = group["Magerr"]

    plt.figure(figsize=(10,6), facecolor='white')

    plt.errorbar(date, mag, yerr=err,
                 fmt='o', markersize=4, capsize=2)

    plt.xlabel("Date (year)", color='black')
    plt.ylabel("V magnitude", color='black')
    plt.title(f"Light Curve - MasterID {master_id}", color='black')

    ax = plt.gca()
    ax.tick_params(axis='both', colors='black')

    for spine in ax.spines.values():
        spine.set_color('black')

    plt.gca().invert_yaxis()
    plt.grid(True, color='white', alpha=0.1)

    plt.savefig(f"lightcurve_plots/lightcurve_{master_id}.png", dpi=300)
    plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from astropy.time import Time

# READ CSV FILE
file_path = r"C:\Users\marya\Downloads\result_web_fileFEkDcn.csv"

df = pd.read_csv(file_path, header=None, dtype=str)

# ADD COLUMN NAMES
df.columns = ["MasterID", "Mag", "Magerr", "RA", "Dec", "MJD", "Blend"]

# CLEAN DATA
df["MasterID"] = df["MasterID"].str.strip()

df["Mag"] = pd.to_numeric(df["Mag"], errors="coerce")
df["Magerr"] = pd.to_numeric(df["Magerr"], errors="coerce")
df["MJD"] = pd.to_numeric(df["MJD"], errors="coerce")

# Remove bad rows
df = df.dropna(subset=["MasterID", "Mag", "Magerr", "MJD"])

# CONVERT MJD TO DATE
t = Time(df["MJD"], format="mjd")
df["date"] = t.to_datetime()

# DEBUG INFO
counts = df["MasterID"].value_counts()

print("Total MasterIDs:", df["MasterID"].nunique())
print("MasterIDs with >=10 rows:", (counts >= 10).sum())

# CREATE OUTPUT FOLDER
output_folder = "lightcurve_plots_sigma"

os.makedirs(output_folder, exist_ok=True)

# LOOP THROUGH MASTERIDS
for master_id, group in df.groupby("MasterID"):

    # Skip MasterIDs with fewer than 10 rows
    if len(group) < 10:
        continue

    # Sort by date
    group = group.sort_values("date")

    # THREE SIGMA CORRECTION
    avg = group["Mag"].mean()
    std = group["Mag"].std()

    lower = avg - 3 * std
    upper = avg + 3 * std

    group_clean = group[(group["Mag"] >= lower) & (group["Mag"] <= upper)]

    # Check if sigma correction changed anything
    changed = len(group_clean) < len(group)

    # Safe filename
    filename_id = str(master_id).replace("/", "_")

    # IF DATA CHANGED -> SUBPLOTS
    if changed:

        fig, axes = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

        # ORIGINAL PLOT
        axes[0].errorbar(group["date"], group["Mag"], yerr=group["Magerr"], fmt='o', markersize=4, capsize=2)

        axes[0].set_title(f"Original Light Curve - MasterID {master_id}")

        axes[0].set_ylabel("Magnitude")

        axes[0].invert_yaxis()

        axes[0].grid(True, alpha=0.3)

        # SIGMA CORRECTED PLOT
        axes[1].errorbar(group_clean["date"], group_clean["Mag"], yerr=group_clean["Magerr"], fmt='o', markersize=4, capsize=2)

        axes[1].set_title(f"3 Sigma Corrected - MasterID {master_id}")

        axes[1].set_xlabel("Date")
        axes[1].set_ylabel("Magnitude")

        axes[1].invert_yaxis()

        axes[1].grid(True, alpha=0.3)

        plt.tight_layout()

        plt.savefig(f"{output_folder}/lightcurve_{filename_id}_comparison.png", dpi=300)

        plt.close()

    # IF NO CHANGE -> ORIGINAL ONLY
    else:

        plt.figure(figsize=(10, 6))

        plt.errorbar(group["date"], group["Mag"], yerr=group["Magerr"], fmt='o', markersize=4, capsize=2)

        plt.title(f"Light Curve - MasterID {master_id}")

        plt.xlabel("Date")
        plt.ylabel("Magnitude")

        plt.gca().invert_yaxis()

        plt.grid(True, alpha=0.3)

        plt.tight_layout()

        plt.savefig(f"{output_folder}/lightcurve_{filename_id}.png", dpi=300)

        plt.close()

# DONE
print("Done.")
print("Plots saved in:", output_folder)
# Out:
# Total MasterIDs: 98
# MasterIDs with >=10 rows: 91
# Done.
# Plots saved in: lightcurve_plots_sigma
